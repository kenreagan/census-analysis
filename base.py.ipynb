# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = 'data/2019-population_census-report-per-county (1).csv'
data = pd.read_csv(path)
data
# Out:
#              County  Total_Population19  Male population 2019  \
# 0           Baringo              666763                336322
# 1             Bomet              875689                434287
# 2           Bungoma             1670570                812146
# 3             Busia              893681                426252
# 4   Elgeyo-Marakwet              454480                227317
# 5              Embu              608599                304208
# 6           Garissa              841353                458975
# 7          Homa Bay             1131950                539560
# 8            Isiolo              268002                139510
# 9           Kajiado             1117840                557098
# 10         Kakamega             1867579                897133
# 11          Kericho              901777                450751
# 12           Kiambu             2417735               1187146
# 13           Kilifi             1453787                704089
# ...

# %%
#kenya's 2019 total population
data['Total_Population19'].sum()
# Out:
# 47564316

# %% [raw]
# ordered population result in each county

# %%
val = data.sort_values(by="Total_Population19", ascending=False)
val
# Out:
#              County  Total_Population19  Male population 2019  \
# 29          Nairobi             4397073               2192452
# 12           Kiambu             2417735               1187146
# 30           Nakuru             2162202               1077272
# 10         Kakamega             1867579                897133
# 2           Bungoma             1670570                812146
# 25             Meru             1545714                767698
# 13           Kilifi             1453787                704089
# 21         Machakos             1421932                710707
# 15            Kisii             1266860                605784
# 27          Mombasa             1208333                610257
# 43      Uasin Gishu             1163186                580269
# 32            Narok             1157873                579042
# 16           Kisumu             1155574                560942
# 17            Kitui             1136187                549003
# ...

# %% [raw]
# top five most populated counties in kenya

# %%
val.head(5)
# Out:
#       County  Total_Population19  Male population 2019  \
# 29   Nairobi             4397073               2192452
# 12    Kiambu             2417735               1187146
# 30    Nakuru             2162202               1077272
# 10  Kakamega             1867579                897133
# 2    Bungoma             1670570                812146
#
#     Female population 2019  Households  Av_HH_Size  LandArea  \
# 29                 2204376     1506888           3       704
# 12                 1230454      795241           3      2539
# 30                 1084835      616046           4      7462
# 10                  970406      433207           4      3020
# 2                   858389      358796           5      3024
#
#     Population Density  Population in 2009 Pop_change  \
# 29                6247             3138369    1258704
# 12                 952             1623282     794453
# 30                 290             1603325     558877
# ...

# %% [raw]
# less populated counties in kenya

# %%
val.tail(10)
# Out:
#              County  Total_Population19  Male population 2019  \
# 44           Vihiga              590013                283678
# 19         Laikipia              518580                259440
# 24         Marsabit              459785                243548
# 4   Elgeyo-Marakwet              454480                227317
# 40    Tharaka-Nithi              393177                193764
# 38     Taita Taveta              340671                173337
# 39       Tana River              315943                158550
# 36          Samburu              310327                156774
# 8            Isiolo              268002                139510
# 20             Lamu              143920                 76103
#
#     Female population 2019  Households  Av_HH_Size  LandArea  \
# 44                  306323      143365           4       564
# 19                  259102      149271           3      9532
# 24                  216219       77495           6     70944
# ...

# %% [raw]
# counties ordered according to land size

# %%
land = data.sort_values(by="LandArea", ascending=False)
land
# Out:
#              County  Total_Population19  Male population 2019  \
# 24         Marsabit              459785                243548
# 42          Turkana              926976                478087
# 45            Wajir              781263                415374
# 6           Garissa              841353                458975
# 39       Tana River              315943                158550
# 17            Kitui             1136187                549003
# 23          Mandera              867457                434976
# 8            Isiolo              268002                139510
# 9           Kajiado             1117840                557098
# 36          Samburu              310327                156774
# 32            Narok             1157873                579042
# 38     Taita Taveta              340671                173337
# 13           Kilifi             1453787                704089
# 0           Baringo              666763                336322
# ...

# %% [raw]
# top 10 largest counties in kenya

# %%
land.head(10)
# Out:
#         County  Total_Population19  Male population 2019  \
# 24    Marsabit              459785                243548
# 42     Turkana              926976                478087
# 45       Wajir              781263                415374
# 6      Garissa              841353                458975
# 39  Tana River              315943                158550
# 17       Kitui             1136187                549003
# 23     Mandera              867457                434976
# 8       Isiolo              268002                139510
# 9      Kajiado             1117840                557098
# 36     Samburu              310327                156774
#
#     Female population 2019  Households  Av_HH_Size  LandArea  \
# 24                  216219       77495           6     70944
# 42                  448868      164519           6     68233
# 45                  365840      127932           6     56773
# 6                   382344      141394           6     44736
# ...

# %% [raw]
# ten smallest counties

# %%
land.tail(10)
# Out:
#          County  Total_Population19  Male population 2019  \
# 41  Trans Nzoia              990341                489107
# 11      Kericho              901777                450751
# 16       Kisumu             1155574                560942
# 3         Busia              893681                426252
# 14    Kirinyaga              610411                302011
# 15        Kisii             1266860                605784
# 33      Nyamira              605576                290907
# 29      Nairobi             4397073               2192452
# 44       Vihiga              590013                283678
# 27      Mombasa             1208333                610257
#
#     Female population 2019  Households  Av_HH_Size  LandArea  \
# 41                  501206      223808           4      2495
# 11                  451008      206036           4      2436
# 16                  594609      300745           4      2085
# 3                   467401      198152           5      1696
# ...

# %% [raw]
# total land area size in sq kilometers

# %%
land['LandArea'].sum()
# Out:
# 580876

# %% [raw]
# graphical representation of the population result in comaprison to 2009

# %%
pop19 = data['Total_Population19'].sum()
pop009 = data['Population in 2009'].sum()

# %%
pop19
# Out:
# 47564316

# %%
pop009
# Out:
# 38610097

# %%
plt.bar(range(2009, 2019), pop009)
# Out:
# <BarContainer object of 10 artists>
